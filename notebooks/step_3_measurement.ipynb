# %% [markdown]
# <a href="https://colab.research.google.com/github/boobopbiboop/burn-wound-measurement/blob/main/step_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import

# %%
import cv2
import numpy as np
import json
from pathlib import Path
from google.colab import drive
import os
import pandas as pd
from tqdm.notebook import tqdm
from glob import glob
import time

# %% [markdown]
# # STEP 1: MOUNT DRIVE & FIND SHARED FOLDER

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
BASE_PATH       = '/content/drive/MyDrive/BurnDetection_ProcessedDataset'
AUGMENTED_DIR   = os.path.join(BASE_PATH, 'augmented')
SEGMENTED_DIR   = os.path.join(BASE_PATH, 'segmented')
MEASUREMENT_DIR = os.path.join(BASE_PATH, 'measured_copy')

# %%
# Buat subfolder untuk setiap method
METHODS = ['gray', 'binary_gray', 'binary_hsv', 'opening', 'closing', 'hole_filled', 'contour']

for method in METHODS:
    method_dir = os.path.join(MEASUREMENT_DIR, method)
    os.makedirs(method_dir, exist_ok=True)

# %%
# NEW: Folder untuk skipped files
SKIPPED_DIR = os.path.join(MEASUREMENT_DIR, 'skipped')
os.makedirs(SKIPPED_DIR, exist_ok=True)

# %%
def get_files(folder):
    return sorted([f for f in glob(os.path.join(folder, "*.*"))
                   if f.lower().endswith(('.png', '.jpg', '.jpeg'))])

augmented_files = get_files(AUGMENTED_DIR)
segmented_files = get_files(SEGMENTED_DIR)

# %%
print(f"Augmented  → {len(augmented_files)} gambar")
print(f"Segmented  → {len(segmented_files)} mask")
print(f"Measured   → {len(os.listdir(MEASUREMENT_DIR)) if os.path.exists(MEASUREMENT_DIR) else 0} file tersimpan")
# Out:
# Augmented  → 8464 gambar
# Segmented  → 59248 mask
# Measured   → 0 file tersimpan

# %% [markdown]
# # MEASUREMENT FUNCTIONS

# %% [markdown]
# Deteksi koin referensi untuk kalibrasi skala

# %%
def detect_coin_for_calibration(image, coin_diameter_cm=2):
    """Deteksi koin referensi dengan filter posisi"""
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    h, w = image.shape[:2]

    lower_gold = np.array([10, 100, 100])
    upper_gold = np.array([30, 255, 255])
    mask = cv2.inRange(hsv, lower_gold, upper_gold)

    kernel = np.ones((5, 5), np.uint8)
    mask = cv2.morphologyEx(mask, cv2.MORPH_CLOSE, kernel)
    mask = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel)

    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    best_circle = None
    max_circularity = 0

    margin = 0.2
    corner_regions = [
        (0, 0, w*margin, h*margin),
        (w*(1-margin), 0, w, h*margin),
        (0, h*(1-margin), w*margin, h),
        (w*(1-margin), h*(1-margin), w, h)
    ]

    for contour in contours:
        area = cv2.contourArea(contour)
        if area < 100:
            continue

        perimeter = cv2.arcLength(contour, True)
        if perimeter == 0:
            continue

        circularity = 4 * np.pi * area / (perimeter * perimeter)

        if circularity > 0.7:
            (x, y), radius = cv2.minEnclosingCircle(contour)

            is_in_corner = False
            for x1, y1, x2, y2 in corner_regions:
                if x1 <= x <= x2 and y1 <= y <= y2:
                    is_in_corner = True
                    break

            score = circularity
            if is_in_corner:
                score *= 2

            if score > max_circularity:
                max_circularity = score
                best_circle = {
                    'center': (int(x), int(y)),
                    'radius': int(radius),
                    'diameter_px': int(radius * 2),
                    'circularity': circularity,
                    'in_corner': is_in_corner
                }

    if best_circle:
        pixels_per_cm = best_circle['diameter_px'] / coin_diameter_cm
        best_circle['pixels_per_cm'] = pixels_per_cm
        best_circle['diameter_cm'] = coin_diameter_cm
        return pixels_per_cm, best_circle

    return None, None

# %%
def check_image_quality(image, mask, coin_info):
    """
    NEW: Quality check untuk skip gambar buruk

    Returns:
        is_valid (bool): True jika gambar valid
        skip_reason (str): Alasan skip jika invalid
        quality_score (float): Score 0-100
    """
    reasons = []
    scores = []

    # CHECK 1: Coin detection
    if coin_info is None:
        reasons.append("No coin detected")
        scores.append(0)
    else:
        if coin_info.get('in_corner', False):
            scores.append(100)  # Perfect
        else:
            reasons.append("Coin in center (not corner)")
            scores.append(50)  # Warning but not skip

    # CHECK 2: Mask quality - ada wound area atau tidak
    mask_area = np.sum(mask > 0)
    mask_percentage = (mask_area / mask.size) * 100

    if mask_area < 100:  # Terlalu kecil
        reasons.append(f"Mask too small ({mask_area} pixels)")
        scores.append(0)
    elif mask_percentage > 80:  # Terlalu besar (kemungkinan error)
        reasons.append(f"Mask too large ({mask_percentage:.1f}% of image)")
        scores.append(0)
    else:
        scores.append(100)

    # CHECK 3: Image brightness (blur detection sederhana)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    brightness = np.mean(gray)

    if brightness < 30:  # Terlalu gelap
        reasons.append(f"Image too dark (brightness: {brightness:.1f})")
        scores.append(30)
    elif brightness > 225:  # Terlalu terang/overexposed
        reasons.append(f"Image too bright (brightness: {brightness:.1f})")
        scores.append(30)
    else:
        scores.append(100)

    # CHECK 4: Blur detection (Laplacian variance)
    laplacian_var = cv2.Laplacian(gray, cv2.CV_64F).var()

    if laplacian_var < 50:  # Terlalu blur
        reasons.append(f"Image too blurry (variance: {laplacian_var:.1f})")
        scores.append(30)
    else:
        scores.append(100)

    # Calculate final score
    quality_score = np.mean(scores)

    # Decision: Skip jika score < 60 ATAU ada critical issue
    critical_issues = ["No coin detected", "Mask too small", "Mask too large"]
    has_critical = any(issue in reasons for issue in critical_issues)

    is_valid = quality_score >= 60 and not has_critical
    skip_reason = "; ".join(reasons) if reasons else "OK"

    return is_valid, skip_reason, quality_score

# %% [markdown]
# Hitung luas area luka dalam cm²

# %%
def calculate_wound_area(binary_mask, pixels_per_cm):
    """Hitung luas area luka dalam cm²"""
    area_pixels = np.sum(binary_mask > 0)

    if pixels_per_cm is None or pixels_per_cm == 0:
        pixels_per_cm = 50

    area_cm2 = area_pixels / (pixels_per_cm ** 2)

    contours, _ = cv2.findContours(binary_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        largest_contour = max(contours, key=cv2.contourArea)
        perimeter_px = cv2.arcLength(largest_contour, True)
        perimeter_cm = perimeter_px / pixels_per_cm

        x, y, w, h = cv2.boundingRect(largest_contour)
        width_cm = w / pixels_per_cm
        height_cm = h / pixels_per_cm
    else:
        perimeter_cm = 0
        width_cm = 0
        height_cm = 0

    area_info = {
        'area_pixels': int(area_pixels),
        'area_cm2': round(area_cm2, 2),
        'perimeter_cm': round(perimeter_cm, 2),
        'width_cm': round(width_cm, 2),
        'height_cm': round(height_cm, 2),
        'pixels_per_cm': round(pixels_per_cm, 2)
    }

    return area_info

# %% [markdown]
# Hitung rasio area luka terhadap referensi

# %%
def calculate_wound_ratio(wound_area_cm2, reference_area_cm2=None):
    """Hitung rasio area luka terhadap referensi"""
    if reference_area_cm2 is None:
        reference_area_cm2 = np.pi * (1 ** 2)

    ratio = wound_area_cm2 / reference_area_cm2

    return {
        'wound_area_cm2': wound_area_cm2,
        'reference_area_cm2': round(reference_area_cm2, 2),
        'ratio': round(ratio, 2),
        'percentage': round(ratio * 100, 2)
    }

# %%
def create_visualization(original, mask, coin_info, area_info, ratio_info, method_name):
    """Create visualization with method label"""
    result_img = original.copy()

    if coin_info:
        center = coin_info['center']
        radius = coin_info['radius']
        coin_color = (255, 0, 0) if coin_info.get('in_corner', False) else (0, 165, 255)

        cv2.circle(result_img, center, radius, coin_color, 2)
        cv2.putText(result_img, f"{coin_info['diameter_cm']}cm REF",
                   (center[0]-30, center[1]-radius-10),
                   cv2.FONT_HERSHEY_SIMPLEX, 0.5, coin_color, 2)

    mask_colored = cv2.applyColorMap(mask, cv2.COLORMAP_JET)
    overlay = cv2.addWeighted(result_img, 0.7, mask_colored, 0.3, 0)

    y_offset = 30
    texts = [
        f"Method: {method_name.upper()}",
        f"Area: {area_info['area_cm2']} sq.cm",
        f"Perimeter: {area_info['perimeter_cm']} cm",
        f"Size: {area_info['width_cm']}x{area_info['height_cm']} cm",
        f"Ratio: {ratio_info['ratio']}x ({ratio_info['percentage']}%)"
    ]

    if coin_info is None:
        texts.insert(1, "WARNING: No coin detected")
        text_color = (0, 0, 255)
    elif not coin_info.get('in_corner', False):
        texts.insert(1, "WARNING: Coin in center")
        text_color = (0, 165, 255)
    else:
        text_color = (0, 255, 0)

    for i, text in enumerate(texts):
        y_pos = y_offset + (i * 30)
        text_size = cv2.getTextSize(text, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)[0]

        cv2.rectangle(overlay, (5, y_pos - 22), (15 + text_size[0], y_pos + 5), (0, 0, 0), -1)
        cv2.putText(overlay, text, (10, y_pos), cv2.FONT_HERSHEY_SIMPLEX, 0.6, text_color, 2)

    return overlay

# %% [markdown]
# Pipeline lengkap: deteksi koin, segmentasi, dan pengukuran area

# %%
def process_image_with_measurement(image_path, segmented_mask_path, output_dir, method_name, enable_quality_check=True):
    """
    Pipeline measurement dengan quality check

    Returns:
        result: measurement result jika valid
        None: jika di-skip karena quality
    """
    original = cv2.imread(image_path)
    mask = cv2.imread(segmented_mask_path, cv2.IMREAD_GRAYSCALE)

    if original is None or mask is None:
        return None

    # Auto-resize mask jika ukuran tidak sama
    if original.shape[:2] != mask.shape[:2]:
        mask = cv2.resize(mask, (original.shape[1], original.shape[0]), interpolation=cv2.INTER_NEAREST)

    # Detect coin dari ORIGINAL
    pixels_per_cm, coin_info = detect_coin_for_calibration(original)

    # NEW: Quality check
    if enable_quality_check:
        is_valid, skip_reason, quality_score = check_image_quality(original, mask, coin_info)

        if not is_valid:
            # Return skip info
            return {
                'filename': Path(image_path).name,
                'method': method_name,
                'skipped': True,
                'skip_reason': skip_reason,
                'quality_score': round(quality_score, 2)
            }

    # Calculate area dari MASK
    area_info = calculate_wound_area(mask, pixels_per_cm)

    # Calculate ratio
    if coin_info:
        coin_area_cm2 = np.pi * (coin_info['diameter_cm'] / 2) ** 2
        ratio_info = calculate_wound_ratio(area_info['area_cm2'], coin_area_cm2)
    else:
        ratio_info = calculate_wound_ratio(area_info['area_cm2'])

    measurement_result = {
        'filename': Path(image_path).name,
        'method': method_name,
        'skipped': False,
        'coin_detected': coin_info is not None,
        'coin_info': coin_info,
        'area_info': area_info,
        'ratio_info': ratio_info
    }

    # Visualize
    result_img = create_visualization(original, mask, coin_info, area_info, ratio_info, method_name)

    # Save result
    output_path = Path(output_dir) / f"measured_{Path(image_path).name}"
    cv2.imwrite(str(output_path), result_img)

    measurement_result['output_path'] = str(output_path)

    return measurement_result

# %% [markdown]
# Batch processing untuk measurement semua gambar

# %%
def batch_area_measurement_multi_method(original_dir, segmented_dir, output_base_dir, methods, enable_quality_check=True):
    """
    Batch processing SEMUA METHOD dengan quality filtering
    """
    all_results = {}
    all_stats = {}
    all_skipped = []

    print(f"{'='*70}")
    print(f"MULTI-METHOD MEASUREMENT WITH QUALITY FILTERING")
    print(f"{'='*70}")
    print(f"Methods to process: {len(methods)}")
    print(f"Quality check: {'ENABLED ✅' if enable_quality_check else 'DISABLED ❌'}")
    print(f"{'='*70}\n")

    for method in methods:
        print(f"\n{'='*70}")
        print(f"Processing Method: {method.upper()}")
        print(f"{'='*70}")

        # Setup paths
        method_output_dir = os.path.join(output_base_dir, method)
        os.makedirs(method_output_dir, exist_ok=True)

        # Find segmented files
        prefix = f"{method}_"
        segmented_files = list(Path(segmented_dir).glob(f"{prefix}*.jpg"))

        if not segmented_files:
            print(f"⚠️  No files found with prefix '{prefix}' - SKIPPING")
            continue

        results = []
        stats = {
            'method': method,
            'total': len(segmented_files),
            'success': 0,
            'skipped': 0,
            'failed': 0,
            'coin_detected': 0,
            'coin_in_corner': 0,
            'coin_in_center': 0,
            'no_coin': 0,
            'skip_reasons': {}
        }

        print(f"Files found: {len(segmented_files)}")

        pbar = tqdm(segmented_files, desc=f"📏 {method}", unit="img")

        for seg_file in pbar:
            orig_filename = seg_file.name.replace(prefix, "")
            orig_path = Path(original_dir) / orig_filename

            if not orig_path.exists():
                stats['failed'] += 1
                continue

            try:
                result = process_image_with_measurement(
                    str(orig_path),
                    str(seg_file),
                    method_output_dir,
                    method,
                    enable_quality_check=enable_quality_check
                )

                if result:
                    # Check if skipped
                    if result.get('skipped', False):
                        stats['skipped'] += 1
                        all_skipped.append(result)

                        # Track skip reasons
                        reason = result['skip_reason']
                        stats['skip_reasons'][reason] = stats['skip_reasons'].get(reason, 0) + 1
                    else:
                        # Valid result
                        results.append(result)
                        stats['success'] += 1

                        if result['coin_detected']:
                            stats['coin_detected'] += 1
                            if result['coin_info'].get('in_corner', False):
                                stats['coin_in_corner'] += 1
                            else:
                                stats['coin_in_center'] += 1
                        else:
                            stats['no_coin'] += 1

                    pbar.set_postfix_str(
                        f"✅{stats['success']} | ⏭️{stats['skipped']} | ❌{stats['failed']}"
                    )
                else:
                    stats['failed'] += 1

            except Exception as e:
                stats['failed'] += 1
                pbar.write(f"❌ Error: {seg_file.name} - {str(e)[:50]}")

        pbar.close()

        # Save results
        if results:
            # JSON
            with open(Path(method_output_dir) / 'measurement_results.json', 'w') as f:
                json.dump(results, f, indent=2)

            # CSV
            flat_results = []
            for r in results:
                flat = {
                    'filename': r['filename'],
                    'method': r['method'],
                    'coin_detected': r['coin_detected'],
                    'coin_in_corner': r['coin_info'].get('in_corner', False) if r['coin_info'] else False,
                    'area_pixels': r['area_info']['area_pixels'],
                    'area_cm2': r['area_info']['area_cm2'],
                    'perimeter_cm': r['area_info']['perimeter_cm'],
                    'width_cm': r['area_info']['width_cm'],
                    'height_cm': r['area_info']['height_cm'],
                    'pixels_per_cm': r['area_info']['pixels_per_cm'],
                    'ratio': r['ratio_info']['ratio'],
                    'percentage': r['ratio_info']['percentage']
                }
                flat_results.append(flat)

            df = pd.DataFrame(flat_results)
            df.to_csv(Path(method_output_dir) / 'measurement_results.csv', index=False)

            all_results[method] = results
            all_stats[method] = stats

        # Print summary
        print(f"\nSummary for {method.upper()}:")
        print(f"   Total: {stats['total']}")
        print(f"   Success: {stats['success']} ({stats['success']/stats['total']*100:.1f}%)")
        print(f"   Skipped: {stats['skipped']} ({stats['skipped']/stats['total']*100:.1f}%)")
        print(f"   Failed: {stats['failed']}")

        if stats['skip_reasons']:
            print(f"\n   Skip Reasons:")
            for reason, count in stats['skip_reasons'].items():
                print(f"      - {reason}: {count}")

    # Save skipped files list
    if all_skipped:
        df_skipped = pd.DataFrame(all_skipped)
        df_skipped.to_csv(Path(output_base_dir) / 'skipped_files.csv', index=False)
        print(f"\nTotal skipped files: {len(all_skipped)}")
        print(f"   Saved to: skipped_files.csv")

    return all_results, all_stats, all_skipped

# %%
def create_comparison_report(all_results, all_stats, output_dir):
    """Create comparison report antar methods"""
    print(f"\n{'='*70}")
    print(f"CREATING COMPARISON REPORT")
    print(f"{'='*70}")

    # Combine all results
    combined_data = []

    for method, results in all_results.items():
        for r in results:
            combined_data.append({
                'filename': r['filename'],
                'method': method,
                'coin_detected': r['coin_detected'],
                'area_cm2': r['area_info']['area_cm2'],
                'perimeter_cm': r['area_info']['perimeter_cm'],
                'width_cm': r['area_info']['width_cm'],
                'height_cm': r['area_info']['height_cm'],
                'ratio': r['ratio_info']['ratio']
            })

    df_all = pd.DataFrame(combined_data)

    # Pivot table
    pivot_area = df_all.pivot_table(index='filename', columns='method', values='area_cm2')
    pivot_area.to_csv(Path(output_dir) / 'comparison_area_by_method.csv')

    # Statistics per method
    stats_summary = []
    for method, results in all_results.items():
        areas = [r['area_info']['area_cm2'] for r in results]
        stats_summary.append({
            'method': method,
            'count': len(results),
            'skipped': all_stats[method]['skipped'],
            'success_rate': round(len(results) / all_stats[method]['total'] * 100, 1),
            'avg_area': round(np.mean(areas), 2),
            'std_area': round(np.std(areas), 2),
            'min_area': round(np.min(areas), 2),
            'max_area': round(np.max(areas), 2),
            'coin_detected': all_stats[method]['coin_detected'],
            'coin_in_corner': all_stats[method]['coin_in_corner']
        })

    df_stats = pd.DataFrame(stats_summary)
    df_stats.to_csv(Path(output_dir) / 'comparison_statistics.csv', index=False)

    # Print comparison
    print(f"\nCOMPARISON STATISTICS:")
    print(df_stats.to_string(index=False))

    print(f"\nFiles saved:")
    print(f"   - comparison_area_by_method.csv")
    print(f"   - comparison_statistics.csv")
    print(f"   - skipped_files.csv")

    return df_all, df_stats

# %%
start_time = time.time()

METHODS_TO_PROCESS = ['binary_gray', 'binary_hsv', 'opening', 'closing', 'hole_filled']

# Set enable_quality_check=True untuk filtering
all_results, all_stats, all_skipped = batch_area_measurement_multi_method(
    original_dir=AUGMENTED_DIR,
    segmented_dir=SEGMENTED_DIR,
    output_base_dir=MEASUREMENT_DIR,
    methods=METHODS_TO_PROCESS,
    enable_quality_check=True  # ← SET TRUE untuk enable filtering
)

# Create comparison
if all_results:
    df_comparison, df_stats = create_comparison_report(all_results, all_stats, MEASUREMENT_DIR)

elapsed = time.time() - start_time
# Out:
# ======================================================================
# MULTI-METHOD MEASUREMENT WITH QUALITY FILTERING
# ======================================================================
# Methods to process: 5
# Quality check: ENABLED ✅
# ======================================================================
#
#
# ======================================================================
# Processing Method: BINARY_GRAY
# ======================================================================
# Files found: 8464
# 📏 binary_gray:   0%|          | 0/8464 [00:00<?, ?img/s]
# Summary for BINARY_GRAY:
#    Total: 8464
#    Success: 6956 (82.2%)
#    Skipped: 1508 (17.8%)
#    Failed: 0
#
#    Skip Reasons:
#       - Mask too large (83.6% of image); Image too bright (brightness: 225.6): 3
#       - Mask too large (84.0% of image); Image too bright (brightness: 233.1): 1
#       - Mask too large (90.7% of image); Image too bright (brightness: 237.0): 3
#       - Mask too large (91.2% of image); Image too bright (brightness: 240.6): 1
#       - Mask too large (90.7% of image); Image too blurry (variance: 48.1): 1
#       - No coin detected: 634
#       - Mask too large (83.0% of image); Image too bright (brightness: 235.2): 4
#       - Mask too large (83.1% of image); Image too bright (brightness: 235.2): 2
#       - Mask too large (85.8% of image); Image too bright (brightness: 240.2); Image too blurry (variance: 47.1): 2
#       - Mask too large (82.8% of image); Image too blurry (variance: 36.4): 2
#       - Mask too large (90.9% of image); Image too bright (brightness: 240.3); Image too blurry (variance: 44.9): 2
#       - Mask too large (90.9% of image); Image too bright (brightness: 240.3); Image too blurry (variance: 45.6): 1
#       - Mask too large (93.3% of image); Image too bright (brightness: 245.9); Image too blurry (variance: 34.5): 1
#       - Mask too large (90.7% of image); Image too blurry (variance: 32.7): 1
#       - Mask too large (80.8% of image); Image too bright (brightness: 233.8); Image too blurry (variance: 14.3): 1
#       - Mask too large (86.2% of image); Image too bright (brightness: 235.1): 3
#       - Mask too large (93.5% of image); Image too bright (brightness: 239.8): 1
#       - Mask too large (86.1% of image); Image too blurry (variance: 45.6): 1
#       - Mask too large (84.9% of image); Image too bright (brightness: 226.9): 1
#       - Mask too large (83.5% of image); Image too bright (brightness: 225.3): 3
#       - Mask too large (84.6% of image); Image too bright (brightness: 228.5): 1
#       - Mask too large (80.1% of image); Image too bright (brightness: 229.1): 3
#       - Mask too large (80.3% of image); Image too bright (brightness: 234.5); Image too blurry (variance: 39.3): 1
#       - Mask too large (80.1% of image); Image too blurry (variance: 38.8): 1
#       - Mask too large (82.6% of image); Image too bright (brightness: 233.2): 3
#       - Mask too large (85.8% of image); Image too bright (brightness: 239.7): 1
#       - Mask too large (84.3% of image); Image too bright (brightness: 226.9): 6
#       - Mask too large (85.7% of image); Image too bright (brightness: 230.5): 2
#       - Mask too large (84.2% of image); Image too blurry (variance: 48.3): 2
#       - Mask too large (87.9% of image); Image too bright (brightness: 229.4); Image too blurry (variance: 46.9): 4
#       - Mask too large (87.9% of image); Image too bright (brightness: 229.4); Image too blurry (variance: 48.6): 2
#       - Mask too large (89.3% of image); Image too bright (brightness: 232.5): 2
#       - Mask too large (87.9% of image); Image too blurry (variance: 34.1): 2
#       - Mask too large (84.5% of image); Image too bright (brightness: 228.4): 3
#       - Mask too large (87.5% of image); Image too bright (brightness: 232.2): 1
#       - Mask too large (84.3% of image); Image too blurry (variance: 47.4): 1
#       - Mask too large (86.0% of image); Image too bright (brightness: 227.4): 2
#       - Mask too large (86.1% of image); Image too bright (brightness: 227.4): 1
#       - Mask too large (86.1% of image); Image too bright (brightness: 229.6): 1
#       - Mask too large (83.1% of image); Image too bright (brightness: 226.5): 1
#       - Mask too large (85.5% of image); Image too bright (brightness: 236.5); Image too blurry (variance: 29.6): 2
#       - Mask too large (85.5% of image); Image too bright (brightness: 236.5); Image too blurry (variance: 30.4): 1
#       - Mask too large (87.6% of image); Image too bright (brightness: 240.6); Image too blurry (variance: 32.6): 1
#       - Mask too large (85.5% of image); Image too blurry (variance: 22.0): 1
#       - Mask too large (83.2% of image); Image too bright (brightness: 226.9): 3
#       - Mask too large (85.6% of image); Image too bright (brightness: 230.7): 1
#       - Mask too large (84.4% of image); Image too bright (brightness: 231.0); Image too blurry (variance: 11.3): 4
#       - Mask too large (84.4% of image); Image too bright (brightness: 231.0); Image too blurry (variance: 11.5): 2
#       - Mask too large (86.0% of image); Image too bright (brightness: 235.6); Image too blurry (variance: 10.4): 2
#       - Mask too large (84.4% of image); Image too blurry (variance: 9.0): 2
#       - Mask too large (86.3% of image); Image too bright (brightness: 228.3): 3
#       - Mask too large (86.7% of image); Image too bright (brightness: 230.7): 1
#       - Mask too large (81.0% of image); Image too bright (brightness: 233.0): 1
#       - Mask too large (83.7% of image); Image too blurry (variance: 8.9): 2
#       - Mask too large (88.1% of image); Image too bright (brightness: 229.8): 3
#       - Mask too large (88.3% of image); Image too bright (brightness: 231.5): 1
#       - Mask too large (88.1% of image); Image too blurry (variance: 42.4): 1
#       - Mask too large (81.7% of image); Image too bright (brightness: 236.0); Image too blurry (variance: 49.3): 2
#       - Mask too large (81.7% of image); Image too bright (brightness: 236.0): 1
#       - Mask too large (87.8% of image); Image too bright (brightness: 242.2); Image too blurry (variance: 40.4): 1
#       - Mask too large (81.1% of image); Image too blurry (variance: 35.7): 1
#       - Mask too large (87.7% of image); Image too bright (brightness: 236.4); Image too blurry (variance: 25.3): 1
#       - Mask too large (85.7% of image); Image too bright (brightness: 228.3); Image too blurry (variance: 42.9): 1
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 34.4): 2
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 35.4): 1
#       - Coin in center (not corner); Image too dark (brightness: 13.8); Image too blurry (variance: 47.4): 1
#       - No coin detected; Image too dark (brightness: 9.8); Image too blurry (variance: 25.0): 1
#       - Mask too large (86.7% of image); Image too bright (brightness: 231.1): 6
#       - Mask too large (86.8% of image); Image too bright (brightness: 233.5): 2
#       - Mask too large (89.1% of image); Image too bright (brightness: 239.7): 1
#       - No coin detected; Image too blurry (variance: 41.4): 2
#       - No coin detected; Image too blurry (variance: 30.1): 1
#       - Mask too large (91.5% of image); Image too bright (brightness: 245.3); Image too blurry (variance: 27.4): 2
#       - Mask too large (91.5% of image); Image too bright (brightness: 245.3); Image too blurry (variance: 27.8): 1
#       - Mask too large (90.6% of image); Image too bright (brightness: 246.5); Image too blurry (variance: 17.9): 1
#       - Mask too large (91.4% of image); Image too blurry (variance: 20.6): 1
#       - Mask too large (85.5% of image); Image too bright (brightness: 230.0): 3
#       - Mask too large (85.6% of image); Image too bright (brightness: 232.7): 1
#       - Mask too large (84.1% of image); Image too bright (brightness: 231.5): 3
#       - Mask too large (84.2% of image); Image too bright (brightness: 235.4): 1
#       - Mask too large (84.1% of image); Image too blurry (variance: 48.6): 1
#       - Mask too large (86.9% of image); Image too bright (brightness: 229.5): 3
#       - Mask too large (87.5% of image); Image too bright (brightness: 232.8): 1
#       - Mask too large (86.9% of image); Image too blurry (variance: 47.5): 1
#       - Mask too large (84.4% of image); Image too bright (brightness: 225.4): 3
#       - Mask too large (84.8% of image); Image too bright (brightness: 228.1): 1
#       - Mask too large (84.4% of image); Image too blurry (variance: 49.3): 1
#       - Mask too large (82.8% of image); Image too bright (brightness: 231.8); Image too blurry (variance: 10.5): 1
#       - Mask too large (81.5% of image); Image too bright (brightness: 228.9): 1
#       - Mask too large (80.8% of image); Image too bright (brightness: 228.5): 2
#       - Mask too large (80.9% of image); Image too bright (brightness: 228.5): 1
#       - Mask too large (80.3% of image); Image too bright (brightness: 233.4); Image too blurry (variance: 47.6): 1
#       - Mask too large (81.0% of image); Image too blurry (variance: 49.2): 1
#       - Mask too large (80.3% of image); Image too bright (brightness: 230.2): 2
#       - Mask too large (86.9% of image); Image too bright (brightness: 229.7): 6
#       - Mask too large (87.8% of image); Image too bright (brightness: 232.0): 2
#       - Mask too large (86.9% of image); Image too blurry (variance: 46.9): 2
#       - Mask too large (83.1% of image); Image too bright (brightness: 225.9): 6
#       - Mask too large (87.2% of image); Image too bright (brightness: 229.5): 2
#       - No coin detected; Image too blurry (variance: 35.4): 2
#       - Mask too large (80.2% of image); Image too bright (brightness: 231.7); Image too blurry (variance: 8.0): 2
#       - Mask too large (86.3% of image); Image too bright (brightness: 231.7): 1
#       - Mask too large (82.1% of image); Image too bright (brightness: 229.3): 6
#       - Mask too large (85.6% of image); Image too bright (brightness: 234.2): 2
#       - Mask too large (86.2% of image); Image too bright (brightness: 236.9): 4
#       - Mask too large (88.8% of image); Image too bright (brightness: 241.4): 1
#       - Mask too large (86.5% of image); Image too bright (brightness: 228.5): 3
#       - Mask too large (89.0% of image); Image too bright (brightness: 232.1): 1
#       - Mask too large (85.8% of image); Image too bright (brightness: 238.5): 3
#       - Mask too large (92.4% of image); Image too bright (brightness: 243.8): 1
#       - Mask too large (83.1% of image); Image too bright (brightness: 230.7); Image too blurry (variance: 49.2): 2
#       - Mask too large (83.3% of image); Image too bright (brightness: 232.0): 3
#       - Mask too large (84.4% of image); Image too bright (brightness: 236.3): 1
#       - Mask too large (87.7% of image); Image too bright (brightness: 232.2): 2
#       - Mask too large (87.8% of image); Image too bright (brightness: 232.2): 1
#       - Mask too large (89.8% of image); Image too bright (brightness: 238.6): 1
#       - Mask too large (88.1% of image); Image too bright (brightness: 231.8): 3
#       - Mask too large (88.3% of image); Image too bright (brightness: 233.6): 1
#       - Mask too large (80.7% of image); Image too bright (brightness: 231.4): 6
#       - Mask too large (80.1% of image); Image too bright (brightness: 236.4): 2
#       - Mask too large (80.7% of image); Image too blurry (variance: 39.4): 2
#       - No coin detected; Image too blurry (variance: 42.6): 2
#       - No coin detected; Image too bright (brightness: 225.7); Image too blurry (variance: 32.1): 2
#       - Mask too large (83.1% of image); Image too bright (brightness: 226.2): 1
#       - Mask too large (80.7% of image); Image too bright (brightness: 229.0); Image too blurry (variance: 25.0): 1
#       - Mask too large (96.4% of image); Image too bright (brightness: 250.6); Image too blurry (variance: 19.4): 1
#       - Mask too large (85.3% of image); Image too bright (brightness: 227.5): 1
#       - Mask too large (83.3% of image); Image too bright (brightness: 234.1); Image too blurry (variance: 20.9): 1
#       - Mask too large (90.9% of image); Image too bright (brightness: 231.6): 1
#       - Mask too large (84.2% of image); Image too blurry (variance: 39.7): 1
#       - Mask too large (80.7% of image); Image too bright (brightness: 229.5): 2
#       - Mask too large (80.8% of image); Image too bright (brightness: 229.5): 1
#       - Mask too large (85.5% of image); Image too bright (brightness: 234.9): 1
#       - Mask too large (80.8% of image); Image too blurry (variance: 36.1): 1
#       - Mask too large (80.6% of image); Image too bright (brightness: 225.5); Image too blurry (variance: 34.0): 2
#       - Mask too large (80.6% of image); Image too bright (brightness: 225.5); Image too blurry (variance: 35.2): 1
#       - Mask too large (83.2% of image); Image too bright (brightness: 230.5); Image too blurry (variance: 37.6): 1
#       - Mask too large (80.6% of image); Image too blurry (variance: 25.1): 1
#       - Mask too large (84.7% of image); Image too bright (brightness: 226.2): 1
#       - Mask too large (90.4% of image); Image too bright (brightness: 242.1); Image too blurry (variance: 48.1): 2
#       - Mask too large (90.4% of image); Image too bright (brightness: 242.1); Image too blurry (variance: 48.5): 1
#       - Mask too large (90.6% of image); Image too bright (brightness: 244.6): 1
#       - Mask too large (90.4% of image); Image too blurry (variance: 33.8): 1
#       - Mask too large (85.3% of image); Image too bright (brightness: 233.4): 3
#       - Mask too large (85.4% of image); Image too bright (brightness: 236.8): 1
#       - Mask too large (80.8% of image); Image too bright (brightness: 232.3); Image too blurry (variance: 22.0): 2
#       - Mask too large (80.8% of image); Image too bright (brightness: 232.3); Image too blurry (variance: 22.7): 1
#       - Mask too large (80.8% of image); Image too blurry (variance: 16.9): 1
#       - Mask too large (82.5% of image); Image too bright (brightness: 227.9): 1
#       - Mask too large (82.3% of image); Image too blurry (variance: 36.1): 1
#       - Mask too large (90.5% of image); Image too bright (brightness: 235.7); Image too blurry (variance: 44.3): 2
#       - Mask too large (90.5% of image); Image too bright (brightness: 235.7); Image too blurry (variance: 44.7): 1
#       - Mask too large (91.3% of image); Image too bright (brightness: 239.1); Image too blurry (variance: 44.1): 1
#       - Mask too large (90.4% of image); Image too blurry (variance: 31.2): 1
#       - Mask too large (85.1% of image); Image too bright (brightness: 229.5): 3
#       - Mask too large (90.5% of image); Image too bright (brightness: 236.6); Image too blurry (variance: 42.7): 1
#       - Mask too large (84.9% of image); Image too blurry (variance: 35.5): 1
#       - Mask too large (85.1% of image); Image too bright (brightness: 231.4); Image too blurry (variance: 29.4): 2
#       - Mask too large (85.1% of image); Image too bright (brightness: 231.4); Image too blurry (variance: 30.1): 1
#       - Mask too large (87.4% of image); Image too bright (brightness: 235.4); Image too blurry (variance: 31.1): 1
#       - Mask too large (85.1% of image); Image too blurry (variance: 21.5): 1
#       - Mask too large (86.8% of image); Image too bright (brightness: 229.9): 3
#       - Mask too large (87.2% of image); Image too bright (brightness: 232.6): 1
#       - Mask too large (82.0% of image); Image too bright (brightness: 226.4): 1
#       - Mask too large (85.5% of image); Image too bright (brightness: 227.7); Image too blurry (variance: 39.6): 2
#       - Mask too large (85.5% of image); Image too bright (brightness: 227.7); Image too blurry (variance: 41.2): 1
#       - Mask too large (87.9% of image); Image too bright (brightness: 231.1); Image too blurry (variance: 46.9): 1
#       - Mask too large (85.4% of image); Image too blurry (variance: 29.9): 1
#       - Mask too large (86.0% of image); Image too bright (brightness: 230.3): 2
#       - Mask too large (86.2% of image); Image too bright (brightness: 226.6): 3
#       - Mask too large (86.6% of image); Image too bright (brightness: 230.5): 1
#       - Mask too large (93.6% of image); Image too bright (brightness: 246.2); Image too blurry (variance: 45.5): 2
#       - Mask too large (93.5% of image); Image too bright (brightness: 246.2); Image too blurry (variance: 45.8): 1
#       - Mask too large (95.9% of image); Image too bright (brightness: 248.3); Image too blurry (variance: 44.3): 1
#       - Mask too large (93.5% of image); Image too blurry (variance: 31.3): 1
#       - Mask too large (83.6% of image); Image too bright (brightness: 230.9): 3
#       - Mask too large (89.3% of image); Image too bright (brightness: 237.6): 1
#       - Mask too large (81.0% of image); Image too bright (brightness: 234.3); Image too blurry (variance: 31.7): 2
#       - Mask too large (81.0% of image); Image too bright (brightness: 234.3); Image too blurry (variance: 32.0): 1
#       - Mask too large (88.3% of image); Image too bright (brightness: 241.8); Image too blurry (variance: 28.7): 1
#       - Mask too large (80.8% of image); Image too blurry (variance: 22.8): 1
#       - Mask too large (83.6% of image); Image too bright (brightness: 228.1): 3
#       - Mask too large (85.6% of image); Image too bright (brightness: 232.5): 1
#       - Mask too large (82.5% of image); Image too bright (brightness: 225.8); Image too blurry (variance: 45.8): 1
#       - No coin detected; Image too blurry (variance: 49.6): 2
#       - No coin detected; Image too blurry (variance: 37.3): 2
#       - Mask too large (81.6% of image); Image too bright (brightness: 230.1): 3
#       - Mask too large (85.4% of image); Image too bright (brightness: 235.5): 1
#       - Mask too large (81.7% of image); Image too blurry (variance: 44.6): 1
#       - Mask too large (84.3% of image); Image too bright (brightness: 238.6); Image too blurry (variance: 33.7): 2
#       - Mask too large (84.2% of image); Image too bright (brightness: 238.6); Image too blurry (variance: 34.3): 1
#       - Mask too large (85.3% of image); Image too bright (brightness: 240.6); Image too blurry (variance: 22.4): 1
#       - Mask too large (84.1% of image); Image too blurry (variance: 25.4): 1
#       - Mask too large (80.1% of image); Image too bright (brightness: 225.5): 3
#       - Mask too large (87.5% of image); Image too bright (brightness: 237.3): 1
#       - No coin detected; Image too blurry (variance: 43.1): 2
#       - Mask too large (80.0% of image); Image too bright (brightness: 233.5): 1
#       - Mask too large (88.1% of image); Image too bright (brightness: 242.2); Image too blurry (variance: 38.7): 1
#       - Mask too large (80.1% of image); Image too blurry (variance: 40.3): 1
#       - No coin detected; Image too blurry (variance: 13.9): 2
#       - No coin detected; Image too blurry (variance: 14.4): 2
#       - No coin detected; Image too blurry (variance: 11.3): 1
#       - Mask too large (81.7% of image); Image too bright (brightness: 232.9): 1
#       - Mask too large (81.7% of image); Image too bright (brightness: 225.7); Image too blurry (variance: 10.7): 2
#       - Mask too large (81.6% of image); Image too bright (brightness: 225.7); Image too blurry (variance: 10.8): 1
#       - Mask too large (82.1% of image); Image too bright (brightness: 230.2); Image too blurry (variance: 9.9): 1
#       - Mask too large (81.7% of image); Image too blurry (variance: 8.4): 1
#       - Mask too large (92.1% of image); Image too bright (brightness: 236.0): 2
#       - Mask too large (92.2% of image); Image too bright (brightness: 236.0): 1
#       - Mask too large (94.1% of image); Image too bright (brightness: 244.8): 1
#       - Mask too large (92.1% of image); Image too blurry (variance: 41.4): 1
#       - Mask too large (91.2% of image); Image too bright (brightness: 241.2): 3
#       - Mask too large (95.8% of image); Image too bright (brightness: 246.1); Image too blurry (variance: 35.2): 1
#       - Mask too large (91.1% of image); Image too blurry (variance: 38.1): 1
#       - Mask too large (87.2% of image); Image too bright (brightness: 243.9); Image too blurry (variance: 41.9): 2
#       - Mask too large (87.2% of image); Image too bright (brightness: 243.9); Image too blurry (variance: 42.8): 1
#       - Mask too large (87.4% of image); Image too bright (brightness: 247.9); Image too blurry (variance: 30.8): 1
#       - Mask too large (87.2% of image); Image too blurry (variance: 30.6): 1
#       - Mask too large (83.1% of image); Image too bright (brightness: 228.1); Image too blurry (variance: 47.2): 2
#       - Mask too large (83.1% of image); Image too bright (brightness: 228.1); Image too blurry (variance: 48.8): 1
#       - Mask too large (87.2% of image); Image too bright (brightness: 232.4); Image too blurry (variance: 43.8): 1
#       - Mask too large (82.9% of image); Image too blurry (variance: 35.2): 1
#       - Mask too large (95.3% of image); Image too bright (brightness: 252.5); Image too blurry (variance: 10.3): 1
#       - Mask too large (83.0% of image); Image too blurry (variance: 21.6): 1
#       - Mask too large (80.4% of image); Image too blurry (variance: 20.6): 1
#       - Mask too large (82.6% of image); Image too blurry (variance: 48.6): 1
#       - No coin detected; Image too blurry (variance: 45.0): 1
#       - Mask too large (84.9% of image); Image too bright (brightness: 232.8); Image too blurry (variance: 38.0): 2
#       - Mask too large (84.9% of image); Image too bright (brightness: 232.8); Image too blurry (variance: 39.1): 1
#       - Mask too large (87.6% of image); Image too bright (brightness: 236.9); Image too blurry (variance: 44.1): 1
#       - Mask too large (84.9% of image); Image too blurry (variance: 27.7): 1
#       - Mask too large (89.4% of image); Image too bright (brightness: 243.3): 3
#       - Mask too large (94.1% of image); Image too bright (brightness: 246.6): 1
#       - Mask too large (89.3% of image); Image too blurry (variance: 38.0): 1
#       - Mask too large (83.3% of image); Image too bright (brightness: 246.0); Image too blurry (variance: 28.5): 2
#       - Mask too large (83.3% of image); Image too bright (brightness: 246.0); Image too blurry (variance: 29.4): 1
#       - Mask too large (82.6% of image); Image too bright (brightness: 237.2): 1
#       - Mask too large (82.2% of image); Image too bright (brightness: 228.4): 1
#       - Mask too large (83.5% of image); Image too bright (brightness: 227.4): 1
#       - Mask too large (87.3% of image); Image too bright (brightness: 234.9): 3
#       - Mask too large (88.5% of image); Image too bright (brightness: 238.4): 1
#       - No coin detected; Mask too large (82.8% of image): 5
#       - Mask too large (91.8% of image); Image too bright (brightness: 235.0): 3
#       - Mask too large (92.4% of image); Image too bright (brightness: 237.4): 1
#       - Mask too large (81.7% of image); Image too bright (brightness: 231.2); Image too blurry (variance: 32.6): 1
#       - Mask too large (84.4% of image); Image too bright (brightness: 234.2): 2
#       - Mask too large (82.7% of image); Image too bright (brightness: 225.3): 3
#       - Mask too large (84.7% of image); Image too bright (brightness: 229.5): 1
#       - Mask too large (82.7% of image); Image too blurry (variance: 48.1): 1
#       - Mask too large (94.1% of image); Image too bright (brightness: 243.1); Image too blurry (variance: 38.0): 1
#       - Mask too large (80.7% of image); Image too bright (brightness: 226.0); Image too blurry (variance: 18.7): 2
#       - Mask too large (80.6% of image); Image too bright (brightness: 226.0); Image too blurry (variance: 19.4): 1
#       - Mask too large (81.6% of image); Image too bright (brightness: 230.7); Image too blurry (variance: 18.4): 1
#       - Mask too large (80.6% of image); Image too blurry (variance: 14.5): 1
#       - Mask too large (81.0% of image); Image too bright (brightness: 229.7); Image too blurry (variance: 39.5): 2
#       - Mask too large (81.0% of image); Image too bright (brightness: 229.7); Image too blurry (variance: 40.4): 1
#       - Mask too large (82.2% of image); Image too bright (brightness: 234.5); Image too blurry (variance: 42.5): 1
#       - Mask too large (80.9% of image); Image too blurry (variance: 29.3): 1
#       - Mask too large (89.6% of image); Image too bright (brightness: 246.7); Image too blurry (variance: 29.4): 2
#       - Mask too large (89.6% of image); Image too bright (brightness: 246.7); Image too blurry (variance: 29.9): 1
#       - Mask too large (94.9% of image); Image too bright (brightness: 250.5); Image too blurry (variance: 11.7): 1
#       - Mask too large (89.0% of image); Image too blurry (variance: 21.7): 1
#       - No coin detected; Image too blurry (variance: 47.9): 1
#       - Mask too large (82.1% of image); Image too bright (brightness: 226.8): 3
#       - Mask too large (82.5% of image); Image too bright (brightness: 230.7): 1
#       - Mask too large (84.0% of image); Image too bright (brightness: 232.1): 3
#       - Mask too large (85.1% of image); Image too bright (brightness: 236.2): 1
#       - Mask too large (87.0% of image); Image too bright (brightness: 231.8): 3
#       - Mask too large (87.1% of image); Image too bright (brightness: 234.2): 1
#       - Mask too large (85.7% of image); Image too bright (brightness: 228.7): 1
#       - Mask too large (86.7% of image); Image too bright (brightness: 234.1): 3
#       - Mask too large (87.8% of image); Image too bright (brightness: 237.5): 1
#       - Mask too large (88.0% of image); Image too blurry (variance: 43.0): 1
#       - No coin detected; Image too blurry (variance: 44.8): 1
#       - Mask too large (83.7% of image); Image too bright (brightness: 229.7): 1
#       - Mask too large (83.8% of image); Image too bright (brightness: 229.6); Image too blurry (variance: 43.3): 2
#       - Mask too large (83.8% of image); Image too bright (brightness: 229.6); Image too blurry (variance: 45.5): 1
#       - Mask too large (86.7% of image); Image too bright (brightness: 234.1); Image too blurry (variance: 45.1): 1
#       - Mask too large (83.6% of image); Image too blurry (variance: 33.4): 1
#       - Mask too large (86.6% of image); Image too bright (brightness: 233.4): 3
#       - Mask too large (86.7% of image); Image too bright (brightness: 236.3): 1
#       - Mask too large (87.9% of image); Image too bright (brightness: 238.5): 3
#       - Mask too large (88.1% of image); Image too bright (brightness: 242.0): 1
#       - Mask too large (86.2% of image); Image too bright (brightness: 245.1); Image too blurry (variance: 30.2): 1
#       - Mask too large (82.1% of image); Image too bright (brightness: 227.0): 2
#       - Mask too large (82.2% of image); Image too bright (brightness: 227.0): 1
#       - Mask too large (82.9% of image); Image too bright (brightness: 230.8): 1
#       - Mask too large (82.1% of image); Image too blurry (variance: 37.9): 1
#       - Mask too large (84.5% of image); Image too bright (brightness: 233.3): 3
#       - Mask too large (85.5% of image); Image too bright (brightness: 237.3): 1
#       - Mask too large (84.5% of image); Image too blurry (variance: 40.6): 1
#       - Mask too large (80.6% of image); Image too bright (brightness: 226.1): 3
#       - Mask too large (80.8% of image); Image too bright (brightness: 230.8): 1
#       - Mask too large (90.5% of image); Image too bright (brightness: 243.8); Image too blurry (variance: 46.0): 2
#       - Mask too large (90.5% of image); Image too bright (brightness: 243.8); Image too blurry (variance: 45.9): 1
#       - Mask too large (90.2% of image); Image too bright (brightness: 246.3); Image too blurry (variance: 32.6): 1
#       - Mask too large (90.5% of image); Image too blurry (variance: 32.4): 1
#       - Mask too large (82.3% of image); Image too bright (brightness: 238.8): 3
#       - Mask too large (88.2% of image); Image too bright (brightness: 244.6); Image too blurry (variance: 33.1): 1
#       - Mask too large (82.3% of image); Image too blurry (variance: 37.3): 1
#       - No coin detected; Mask too large (92.0% of image): 1
#       - Mask too large (83.5% of image); Image too bright (brightness: 227.8): 2
#       - Mask too large (87.3% of image); Image too bright (brightness: 242.4): 3
#       - Mask too large (89.8% of image); Image too bright (brightness: 246.4); Image too blurry (variance: 42.1): 1
#       - Mask too large (87.0% of image); Image too bright (brightness: 233.7): 3
#       - Mask too large (88.7% of image); Image too bright (brightness: 237.5): 1
#       - Mask too large (83.4% of image); Image too bright (brightness: 244.6); Image too blurry (variance: 35.7): 2
#       - Mask too large (83.3% of image); Image too bright (brightness: 244.6); Image too blurry (variance: 35.9): 1
#       - Mask too large (93.9% of image); Image too bright (brightness: 250.4); Image too blurry (variance: 31.5): 1
#       - Mask too large (83.4% of image); Image too blurry (variance: 25.1): 1
#       - Mask too large (90.8% of image); Image too bright (brightness: 236.9): 1
#       - Mask too large (85.0% of image); Image too bright (brightness: 235.6): 1
#       - Mask too large (83.2% of image); Image too bright (brightness: 229.1): 3
#       - Mask too large (84.7% of image); Image too bright (brightness: 233.6): 1
#       - Mask too large (84.2% of image); Image too bright (brightness: 227.6): 1
#       - Mask too large (83.7% of image); Image too bright (brightness: 230.0); Image too blurry (variance: 37.9): 2
#       - Mask too large (83.7% of image); Image too bright (brightness: 230.0); Image too blurry (variance: 38.9): 1
#       - Mask too large (86.3% of image); Image too bright (brightness: 234.2); Image too blurry (variance: 40.5): 1
#       - Mask too large (83.6% of image); Image too blurry (variance: 27.8): 1
#       - No coin detected; Image too blurry (variance: 43.9): 2
#       - Mask too large (91.3% of image); Image too bright (brightness: 238.3): 3
#       - Mask too large (92.3% of image); Image too bright (brightness: 240.4); Image too blurry (variance: 49.1): 1
#       - Mask too large (91.2% of image); Image too blurry (variance: 40.6): 1
#       - Mask too large (94.0% of image); Image too bright (brightness: 237.1): 3
#       - Mask too large (97.6% of image); Image too bright (brightness: 242.9); Image too blurry (variance: 45.8): 1
#       - Mask too large (84.1% of image); Image too blurry (variance: 47.0): 1
#       - Mask too large (95.8% of image); Image too bright (brightness: 248.9); Image too blurry (variance: 37.7): 1
#       - Mask too large (81.0% of image); Image too bright (brightness: 226.5); Image too blurry (variance: 13.8): 1
#       - Mask too large (91.3% of image); Image too bright (brightness: 230.8): 3
#       - Mask too large (93.9% of image); Image too bright (brightness: 240.5): 1
#       - No coin detected; Image too blurry (variance: 45.9): 1
#       - Mask too large (84.2% of image); Image too bright (brightness: 225.7): 2
#       - Mask too large (84.1% of image); Image too bright (brightness: 225.7): 1
#       - Mask too large (84.8% of image); Image too bright (brightness: 228.3): 1
#       - Mask too large (80.1% of image); Image too bright (brightness: 236.7); Image too blurry (variance: 32.4): 1
#       - Mask too large (85.3% of image); Image too bright (brightness: 230.7): 1
#       - Mask too large (87.1% of image); Image too bright (brightness: 234.5); Image too blurry (variance: 42.5): 1
#       - Mask too large (82.5% of image); Image too bright (brightness: 229.3): 3
#       - Mask too large (82.7% of image); Image too bright (brightness: 233.4): 1
#       - No coin detected; Image too dark (brightness: 27.9): 1
#       - Mask too large (85.9% of image); Image too bright (brightness: 239.4); Image too blurry (variance: 44.5): 2
#       - Mask too large (86.0% of image); Image too bright (brightness: 239.4); Image too blurry (variance: 45.1): 1
#       - Mask too large (93.7% of image); Image too bright (brightness: 245.5); Image too blurry (variance: 37.3): 1
#       - Mask too large (85.9% of image); Image too blurry (variance: 32.1): 1
#       - Mask too large (89.9% of image); Image too bright (brightness: 236.6): 3
#       - Mask too large (90.3% of image); Image too bright (brightness: 239.4): 1
#       - Mask too large (88.8% of image); Image too bright (brightness: 232.8): 3
#       - Mask too large (90.3% of image); Image too bright (brightness: 235.2): 1
#       - Mask too large (84.0% of image); Image too bright (brightness: 227.9): 3
#       - Mask too large (84.6% of image); Image too bright (brightness: 231.3): 1
#       - Mask too large (88.0% of image); Image too bright (brightness: 241.7); Image too blurry (variance: 40.3): 1
#       - No coin detected; Mask too large (85.8% of image): 3
#       - No coin detected; Mask too large (87.5% of image): 1
#       - Mask too large (85.0% of image); Image too bright (brightness: 231.5): 3
#       - Mask too large (85.9% of image); Image too bright (brightness: 234.8): 1
#       - No coin detected; Mask too large (88.1% of image): 3
#       - No coin detected; Mask too large (89.2% of image): 4
#       - Mask too large (86.6% of image); Image too bright (brightness: 228.4): 1
#       - Mask too large (85.9% of image); Image too bright (brightness: 232.8): 3
#       - Mask too large (86.8% of image); Image too bright (brightness: 235.9): 1
#       - No coin detected; Image too blurry (variance: 35.6): 2
#       - No coin detected; Image too blurry (variance: 36.2): 1
#       - No coin detected; Image too blurry (variance: 48.9): 1
#       - No coin detected; Image too blurry (variance: 34.7): 2
#       - No coin detected; Image too blurry (variance: 35.5): 1
#       - No coin detected; Image too blurry (variance: 38.7): 1
#       - No coin detected; Image too blurry (variance: 26.7): 1
#       - Mask too large (82.1% of image); Image too bright (brightness: 241.4); Image too blurry (variance: 35.7): 2
#       - Mask too large (82.1% of image); Image too bright (brightness: 241.4); Image too blurry (variance: 36.0): 1
#       - Mask too large (92.4% of image); Image too bright (brightness: 247.7); Image too blurry (variance: 26.4): 1
#       - Mask too large (81.4% of image); Image too blurry (variance: 25.0): 1
#       - Mask too large (86.6% of image); Image too bright (brightness: 225.5): 3
#       - Mask too large (87.9% of image); Image too bright (brightness: 230.3): 1
#       - Mask too large (86.5% of image); Image too blurry (variance: 43.8): 1
#       - Mask too large (80.3% of image); Image too blurry (variance: 27.4): 1
#       - Mask too large (82.5% of image); Image too bright (brightness: 234.1): 3
#       - Mask too large (87.1% of image); Image too bright (brightness: 239.9); Image too blurry (variance: 41.8): 1
#       - Mask too large (82.4% of image); Image too blurry (variance: 47.5): 1
#       - Mask too large (86.8% of image); Image too bright (brightness: 228.7): 3
#       - Mask too large (87.0% of image); Image too bright (brightness: 230.5): 1
#       - Mask too large (80.2% of image); Image too bright (brightness: 230.8): 1
#       - Mask too large (80.8% of image); Image too bright (brightness: 232.2); Image too blurry (variance: 20.9): 1
#       - Mask too large (86.4% of image); Image too bright (brightness: 230.6); Image too blurry (variance: 21.2): 2
#       - Mask too large (86.4% of image); Image too bright (brightness: 230.6); Image too blurry (variance: 22.1): 1
#       - Mask too large (87.5% of image); Image too bright (brightness: 233.5); Image too blurry (variance: 25.4): 1
#       - Mask too large (86.4% of image); Image too blurry (variance: 16.2): 1
#       - Mask too large (81.6% of image); Image too bright (brightness: 225.6); Image too blurry (variance: 16.5): 2
#       - Mask too large (81.6% of image); Image too bright (brightness: 225.6); Image too blurry (variance: 16.7): 1
#       - Mask too large (84.8% of image); Image too bright (brightness: 230.4); Image too blurry (variance: 13.9): 1
#       - Mask too large (81.6% of image); Image too blurry (variance: 12.8): 1
#       - Mask too large (84.2% of image); Image too bright (brightness: 230.9): 3
#       - Mask too large (84.7% of image); Image too bright (brightness: 234.6): 1
#       - Mask too large (84.2% of image); Image too blurry (variance: 36.4): 1
#       - Mask too large (87.6% of image); Image too bright (brightness: 233.5): 3
#       - Mask too large (88.6% of image); Image too bright (brightness: 236.5): 1
#       - Mask too large (83.1% of image); Image too bright (brightness: 230.9); Image too blurry (variance: 43.5): 2
#       - Mask too large (83.1% of image); Image too bright (brightness: 230.9); Image too blurry (variance: 44.0): 1
#       - Mask too large (82.7% of image); Image too bright (brightness: 234.6); Image too blurry (variance: 43.7): 1
#       - Mask too large (83.1% of image); Image too blurry (variance: 30.6): 1
#       - Mask too large (83.8% of image); Image too bright (brightness: 236.4); Image too blurry (variance: 35.3): 2
#       - Mask too large (83.8% of image); Image too bright (brightness: 236.4); Image too blurry (variance: 35.8): 1
#       - Mask too large (87.9% of image); Image too bright (brightness: 241.7); Image too blurry (variance: 33.0): 1
#       - Mask too large (83.8% of image); Image too blurry (variance: 25.4): 1
#       - Mask too large (80.3% of image); Image too bright (brightness: 226.1); Image too blurry (variance: 38.4): 2
#       - Mask too large (80.3% of image); Image too bright (brightness: 226.1); Image too blurry (variance: 39.4): 1
#       - Mask too large (80.6% of image); Image too bright (brightness: 230.9); Image too blurry (variance: 38.5): 1
#       - Mask too large (80.9% of image); Image too bright (brightness: 230.8); Image too blurry (variance: 39.2): 2
#       - Mask too large (81.0% of image); Image too bright (brightness: 230.8); Image too blurry (variance: 39.8): 1
#       - Mask too large (80.6% of image); Image too blurry (variance: 28.8): 1
#       - Mask too large (82.1% of image); Image too blurry (variance: 31.4): 1
#       - Mask too large (83.5% of image); Image too bright (brightness: 230.3): 3
#       - Mask too large (83.7% of image); Image too bright (brightness: 235.6): 1
#       - Mask too large (86.0% of image); Image too bright (brightness: 240.5): 3
#       - Mask too large (96.1% of image); Image too bright (brightness: 245.5): 1
#       - Mask too large (85.9% of image); Image too blurry (variance: 35.2): 1
#       - Mask too large (84.4% of image); Image too bright (brightness: 230.6): 3
#       - Mask too large (85.5% of image); Image too bright (brightness: 234.1): 1
#       - Mask too large (86.6% of image); Image too bright (brightness: 235.4): 3
#       - Mask too large (93.5% of image); Image too bright (brightness: 240.0): 1
#       - Mask too large (80.5% of image); Image too bright (brightness: 235.2): 3
#       - Mask too large (80.3% of image); Image too bright (brightness: 241.3); Image too blurry (variance: 44.9): 1
#       - Mask too large (80.5% of image); Image too blurry (variance: 42.6): 1
#       - Mask too large (85.9% of image); Image too bright (brightness: 237.8): 2
#       - Mask too large (85.8% of image); Image too bright (brightness: 237.8): 1
#       - Mask too large (85.9% of image); Image too bright (brightness: 239.7); Image too blurry (variance: 34.0): 1
#       - Mask too large (85.9% of image); Image too blurry (variance: 48.4): 1
#       - Mask too large (94.6% of image); Image too bright (brightness: 249.9); Image too blurry (variance: 20.7): 2
#       - Mask too large (94.7% of image); Image too bright (brightness: 249.9); Image too blurry (variance: 21.2): 1
#       - Mask too large (97.5% of image); Image too bright (brightness: 252.8); Image too blurry (variance: 12.7): 1
#       - Mask too large (94.6% of image); Image too blurry (variance: 16.2): 1
#       - Mask too large (81.5% of image); Image too bright (brightness: 226.5): 3
#       - Mask too large (91.8% of image); Image too bright (brightness: 238.3): 1
#       - Mask too large (86.8% of image); Image too bright (brightness: 238.3): 2
#       - Mask too large (86.9% of image); Image too bright (brightness: 238.3): 1
#       - Mask too large (86.8% of image); Image too bright (brightness: 241.9): 1
#       - Mask too large (86.9% of image); Image too blurry (variance: 48.5): 1
#       - No coin detected; Mask too large (85.6% of image): 3
#       - No coin detected; Mask too large (89.5% of image): 1
#       - Mask too large (85.5% of image); Image too blurry (variance: 46.1): 1
#       - Mask too large (80.1% of image); Image too bright (brightness: 230.9); Image too blurry (variance: 13.6): 4
#       - Mask too large (80.1% of image); Image too bright (brightness: 230.9); Image too blurry (variance: 13.9): 2
#       - Mask too large (83.1% of image); Image too bright (brightness: 237.4); Image too blurry (variance: 12.6): 2
#       - Mask too large (86.3% of image); Image too bright (brightness: 236.1): 3
#       - Mask too large (88.3% of image); Image too bright (brightness: 239.6): 1
#       - No coin detected; Image too blurry (variance: 29.6): 2
#       - No coin detected; Image too blurry (variance: 30.4): 1
#       - Mask too large (83.4% of image); Image too bright (brightness: 230.4): 1
#       - Mask too large (82.6% of image); Image too bright (brightness: 232.2); Image too blurry (variance: 48.9): 1
#       - Mask too large (83.6% of image); Image too bright (brightness: 227.4): 3
#       - Mask too large (86.7% of image); Image too bright (brightness: 232.2): 1
#       - Coin in center (not corner); Mask too large (96.5% of image); Image too blurry (variance: 46.0): 1
#       - Mask too large (83.3% of image); Image too bright (brightness: 226.3): 1
#       - Mask too large (82.4% of image); Image too blurry (variance: 38.7): 1
#       - Mask too large (89.2% of image); Image too bright (brightness: 241.7): 3
#       - Mask too large (90.1% of image); Image too bright (brightness: 245.1): 1
#       - Mask too large (89.2% of image); Image too blurry (variance: 42.7): 1
#       - Mask too large (82.8% of image); Image too bright (brightness: 230.2); Image too blurry (variance: 10.5): 2
#       - Mask too large (82.8% of image); Image too bright (brightness: 230.2); Image too blurry (variance: 10.6): 1
#       - Mask too large (83.9% of image); Image too bright (brightness: 234.8); Image too blurry (variance: 9.2): 1
#       - Mask too large (82.8% of image); Image too blurry (variance: 8.4): 1
#       - Mask too large (85.7% of image); Image too bright (brightness: 234.9): 1
#       - Mask too large (81.6% of image); Image too bright (brightness: 228.1): 1
#       - Mask too large (81.8% of image); Image too bright (brightness: 235.0): 3
#       - Mask too large (85.7% of image); Image too bright (brightness: 240.8): 1
#       - Mask too large (81.7% of image); Image too blurry (variance: 49.7): 1
#       - Mask too large (80.8% of image); Image too bright (brightness: 227.1): 1
#       - Mask too large (82.6% of image); Image too bright (brightness: 234.3); Image too blurry (variance: 37.5): 2
#       - Mask too large (82.6% of image); Image too bright (brightness: 234.3); Image too blurry (variance: 37.9): 1
#       - Mask too large (87.2% of image); Image too bright (brightness: 240.0); Image too blurry (variance: 31.4): 1
#       - Mask too large (82.5% of image); Image too blurry (variance: 26.5): 1
#       - Mask too large (83.9% of image); Image too bright (brightness: 227.0): 3
#       - Mask too large (84.0% of image); Image too bright (brightness: 229.9): 1
#       - Mask too large (80.2% of image); Image too bright (brightness: 229.0); Image too blurry (variance: 10.5): 1
#       - Mask too large (83.7% of image); Image too bright (brightness: 234.3): 2
#       - Mask too large (83.6% of image); Image too bright (brightness: 234.3): 1
#       - Mask too large (84.8% of image); Image too bright (brightness: 239.4): 1
#       - Mask too large (83.7% of image); Image too blurry (variance: 39.2): 1
#       - Mask too large (84.0% of image); Image too bright (brightness: 227.1): 2
#       - Mask too large (90.6% of image); Image too bright (brightness: 238.4): 3
#       - Mask too large (92.9% of image); Image too bright (brightness: 242.2): 1
#       - Mask too large (81.9% of image); Image too bright (brightness: 232.0): 3
#       - Mask too large (82.5% of image); Image too bright (brightness: 236.7); Image too blurry (variance: 49.1): 1
#       - Mask too large (81.9% of image); Image too blurry (variance: 41.9): 1
#       - Mask too large (88.2% of image); Image too bright (brightness: 229.1): 3
#       - Mask too large (89.5% of image); Image too bright (brightness: 232.7): 1
#       - Mask too large (90.1% of image); Image too bright (brightness: 237.6): 2
#       - Mask too large (90.0% of image); Image too bright (brightness: 237.6): 1
#       - Mask too large (90.3% of image); Image too bright (brightness: 239.6): 1
#       - No coin detected; Image too blurry (variance: 46.8): 1
#       - Mask too large (88.4% of image); Image too bright (brightness: 243.0); Image too blurry (variance: 24.8): 1
#       - Mask too large (82.3% of image); Image too bright (brightness: 227.3): 3
#       - Mask too large (82.7% of image); Image too bright (brightness: 231.1): 1
#       - Mask too large (84.7% of image); Image too bright (brightness: 231.8); Image too blurry (variance: 34.3): 2
#       - Mask too large (84.7% of image); Image too bright (brightness: 231.8); Image too blurry (variance: 35.8): 1
#       - Mask too large (86.9% of image); Image too bright (brightness: 235.8); Image too blurry (variance: 32.6): 1
#       - Mask too large (84.7% of image); Image too blurry (variance: 26.5): 1
#       - Mask too large (80.3% of image); Image too bright (brightness: 228.1); Image too blurry (variance: 47.9): 1
#       - No coin detected; Image too blurry (variance: 35.9): 1
#       - Mask too large (86.8% of image); Image too bright (brightness: 233.6): 1
#       - Mask too large (91.3% of image); Image too bright (brightness: 238.2): 3
#       - Mask too large (91.5% of image); Image too bright (brightness: 240.1): 1
#       - No coin detected; Image too blurry (variance: 49.0): 1
#       - Mask too large (82.1% of image); Image too bright (brightness: 234.9); Image too blurry (variance: 27.1): 2
#       - Mask too large (82.1% of image); Image too bright (brightness: 234.9); Image too blurry (variance: 27.2): 1
#       - Mask too large (89.2% of image); Image too bright (brightness: 241.4); Image too blurry (variance: 30.2): 1
#       - Mask too large (82.2% of image); Image too blurry (variance: 19.1): 1
#       - Mask too large (88.9% of image); Image too bright (brightness: 235.6): 3
#       - Mask too large (89.5% of image); Image too bright (brightness: 239.7): 1
#       - No coin detected; Image too dark (brightness: 29.8): 1
#       - No coin detected; Image too blurry (variance: 45.6): 1
#       - Mask too large (87.3% of image); Image too bright (brightness: 236.8): 3
#       - Mask too large (93.9% of image); Image too bright (brightness: 240.6): 1
#       - Mask too large (83.4% of image); Image too bright (brightness: 225.1): 3
#       - Mask too large (83.5% of image); Image too bright (brightness: 228.1): 1
#       - Mask too large (87.8% of image); Image too bright (brightness: 244.5); Image too blurry (variance: 28.1): 1
#       - Mask too large (87.4% of image); Image too bright (brightness: 240.0): 3
#       - Mask too large (86.7% of image); Image too bright (brightness: 242.0); Image too blurry (variance: 37.7): 1
#       - Mask too large (87.4% of image); Image too blurry (variance: 38.3): 1
#       - Mask too large (83.5% of image); Image too bright (brightness: 232.8): 3
#       - Mask too large (94.8% of image); Image too bright (brightness: 236.1): 1
#       - Mask too large (81.8% of image); Image too bright (brightness: 228.3): 3
#       - Mask too large (88.2% of image); Image too bright (brightness: 232.8): 1
#       - Mask too large (84.7% of image); Image too bright (brightness: 233.1): 1
#       - Mask too large (81.6% of image); Image too bright (brightness: 227.8): 1
#       - Mask too large (81.1% of image); Image too bright (brightness: 227.9); Image too blurry (variance: 47.6): 1
#       - Mask too large (80.6% of image); Image too bright (brightness: 232.9): 3
# ...
#       - No coin detected; Image too blurry (variance: 13.9): 2
#       - No coin detected; Image too blurry (variance: 14.4): 2
#       - No coin detected; Image too blurry (variance: 11.3): 1
#       - No coin detected; Image too blurry (variance: 45.0): 1
#       - No coin detected; Mask too large (82.6% of image): 5
#       - No coin detected; Image too blurry (variance: 47.9): 1
#       - Mask too large (99.2% of image); Image too blurry (variance: 43.0): 1
#       - No coin detected; Image too blurry (variance: 44.8): 1
#       - No coin detected; Image too blurry (variance: 43.9): 2
#       - No coin detected; Image too blurry (variance: 45.9): 1
#       - No coin detected; Image too dark (brightness: 27.9): 1
#       - No coin detected; Image too blurry (variance: 35.6): 2
#       - No coin detected; Image too blurry (variance: 36.2): 1
#       - No coin detected; Image too blurry (variance: 48.9): 1
#       - No coin detected; Image too blurry (variance: 34.7): 2
#       - No coin detected; Image too blurry (variance: 35.5): 1
#       - No coin detected; Image too blurry (variance: 38.7): 1
#       - No coin detected; Image too blurry (variance: 26.7): 1
#       - No coin detected; Mask too large (83.5% of image): 1
#       - No coin detected; Mask too large (83.6% of image): 2
#       - No coin detected; Mask too large (87.1% of image): 3
#       - No coin detected; Mask too large (91.6% of image): 1
#       - Mask too large (87.0% of image); Image too blurry (variance: 46.1): 1
#       - No coin detected; Image too blurry (variance: 29.6): 2
#       - No coin detected; Image too blurry (variance: 30.4): 1
#       - Coin in center (not corner); Mask too large (94.1% of image); Image too blurry (variance: 46.0): 1
#       - No coin detected; Image too blurry (variance: 46.8): 1
#       - No coin detected; Image too blurry (variance: 35.9): 1
#       - No coin detected; Image too blurry (variance: 49.0): 1
#       - No coin detected; Image too dark (brightness: 29.8): 1
#       - No coin detected; Image too blurry (variance: 45.6): 1
#       - No coin detected; Image too dark (brightness: 28.9): 1
#
# ======================================================================
# Processing Method: OPENING
# ======================================================================
# Files found: 8464
# 📏 opening:   0%|          | 0/8464 [00:00<?, ?img/s]
# Summary for OPENING:
#    Total: 8464
#    Success: 7755 (91.6%)
#    Skipped: 709 (8.4%)
#    Failed: 0
#
#    Skip Reasons:
#       - No coin detected: 644
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 34.4): 2
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 35.4): 1
#       - Coin in center (not corner); Image too dark (brightness: 13.8); Image too blurry (variance: 47.4): 1
#       - No coin detected; Image too dark (brightness: 9.8); Image too blurry (variance: 25.0): 1
#       - No coin detected; Image too blurry (variance: 41.4): 2
#       - No coin detected; Image too blurry (variance: 30.1): 1
#       - No coin detected; Image too blurry (variance: 35.4): 2
#       - No coin detected; Image too blurry (variance: 42.6): 2
#       - No coin detected; Image too bright (brightness: 225.7); Image too blurry (variance: 32.1): 2
#       - No coin detected; Image too blurry (variance: 49.6): 2
#       - No coin detected; Image too blurry (variance: 37.3): 2
#       - No coin detected; Image too blurry (variance: 43.1): 2
#       - No coin detected; Image too blurry (variance: 13.9): 2
#       - No coin detected; Image too blurry (variance: 14.4): 2
#       - No coin detected; Image too blurry (variance: 11.3): 1
#       - No coin detected; Image too blurry (variance: 45.0): 1
#       - No coin detected; Mask too large (82.5% of image): 2
#       - No coin detected; Mask too large (82.6% of image): 3
#       - No coin detected; Image too blurry (variance: 47.9): 1
#       - Mask too large (99.2% of image); Image too blurry (variance: 43.0): 1
#       - No coin detected; Image too blurry (variance: 44.8): 1
#       - No coin detected; Image too blurry (variance: 43.9): 2
#       - No coin detected; Image too blurry (variance: 45.9): 1
#       - No coin detected; Image too dark (brightness: 27.9): 1
#       - No coin detected; Image too blurry (variance: 35.6): 2
#       - No coin detected; Image too blurry (variance: 36.2): 1
#       - No coin detected; Image too blurry (variance: 48.9): 1
#       - No coin detected; Image too blurry (variance: 34.7): 2
#       - No coin detected; Image too blurry (variance: 35.5): 1
#       - No coin detected; Image too blurry (variance: 38.7): 1
#       - No coin detected; Image too blurry (variance: 26.7): 1
#       - No coin detected; Mask too large (83.5% of image): 3
#       - No coin detected; Mask too large (86.9% of image): 3
#       - No coin detected; Mask too large (91.4% of image): 1
#       - Mask too large (86.7% of image); Image too blurry (variance: 46.1): 1
#       - No coin detected; Image too blurry (variance: 29.6): 2
#       - No coin detected; Image too blurry (variance: 30.4): 1
#       - Coin in center (not corner); Mask too large (94.0% of image); Image too blurry (variance: 46.0): 1
#       - No coin detected; Image too blurry (variance: 46.8): 1
#       - No coin detected; Image too blurry (variance: 35.9): 1
#       - No coin detected; Image too blurry (variance: 49.0): 1
#       - No coin detected; Image too dark (brightness: 29.8): 1
#       - No coin detected; Image too blurry (variance: 45.6): 1
#       - No coin detected; Image too dark (brightness: 28.9): 1
#
# ======================================================================
# Processing Method: CLOSING
# ======================================================================
# Files found: 8464
# 📏 closing:   0%|          | 0/8464 [00:00<?, ?img/s]
# Summary for CLOSING:
#    Total: 8464
#    Success: 7755 (91.6%)
#    Skipped: 709 (8.4%)
#    Failed: 0
#
#    Skip Reasons:
#       - No coin detected: 644
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 34.4): 2
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 35.4): 1
#       - Coin in center (not corner); Image too dark (brightness: 13.8); Image too blurry (variance: 47.4): 1
#       - No coin detected; Image too dark (brightness: 9.8); Image too blurry (variance: 25.0): 1
#       - No coin detected; Image too blurry (variance: 41.4): 2
#       - No coin detected; Image too blurry (variance: 30.1): 1
#       - No coin detected; Image too blurry (variance: 35.4): 2
#       - No coin detected; Image too blurry (variance: 42.6): 2
#       - No coin detected; Image too bright (brightness: 225.7); Image too blurry (variance: 32.1): 2
#       - No coin detected; Image too blurry (variance: 49.6): 2
#       - No coin detected; Image too blurry (variance: 37.3): 2
#       - No coin detected; Image too blurry (variance: 43.1): 2
#       - No coin detected; Image too blurry (variance: 13.9): 2
#       - No coin detected; Image too blurry (variance: 14.4): 2
#       - No coin detected; Image too blurry (variance: 11.3): 1
#       - No coin detected; Image too blurry (variance: 45.0): 1
#       - No coin detected; Mask too large (82.8% of image): 3
#       - No coin detected; Mask too large (82.9% of image): 2
#       - No coin detected; Image too blurry (variance: 47.9): 1
#       - Mask too large (99.2% of image); Image too blurry (variance: 43.0): 1
#       - No coin detected; Image too blurry (variance: 44.8): 1
#       - No coin detected; Image too blurry (variance: 43.9): 2
#       - No coin detected; Image too blurry (variance: 45.9): 1
#       - No coin detected; Image too dark (brightness: 27.9): 1
#       - No coin detected; Image too blurry (variance: 35.6): 2
#       - No coin detected; Image too blurry (variance: 36.2): 1
#       - No coin detected; Image too blurry (variance: 48.9): 1
#       - No coin detected; Image too blurry (variance: 34.7): 2
#       - No coin detected; Image too blurry (variance: 35.5): 1
#       - No coin detected; Image too blurry (variance: 38.7): 1
#       - No coin detected; Image too blurry (variance: 26.7): 1
#       - No coin detected; Mask too large (83.5% of image): 3
#       - No coin detected; Mask too large (86.9% of image): 3
#       - No coin detected; Mask too large (91.4% of image): 1
#       - Mask too large (86.8% of image); Image too blurry (variance: 46.1): 1
#       - No coin detected; Image too blurry (variance: 29.6): 2
#       - No coin detected; Image too blurry (variance: 30.4): 1
#       - Coin in center (not corner); Mask too large (94.0% of image); Image too blurry (variance: 46.0): 1
#       - No coin detected; Image too blurry (variance: 46.8): 1
#       - No coin detected; Image too blurry (variance: 35.9): 1
#       - No coin detected; Image too blurry (variance: 49.0): 1
#       - No coin detected; Image too dark (brightness: 29.8): 1
#       - No coin detected; Image too blurry (variance: 45.6): 1
#       - No coin detected; Image too dark (brightness: 28.9): 1
#
# ======================================================================
# Processing Method: HOLE_FILLED
# ======================================================================
# Files found: 8464
# 📏 hole_filled:   0%|          | 0/8464 [00:00<?, ?img/s]
# Summary for HOLE_FILLED:
#    Total: 8464
#    Success: 7753 (91.6%)
#    Skipped: 711 (8.4%)
#    Failed: 0
#
#    Skip Reasons:
#       - No coin detected: 560
#       - No coin detected; Mask too large (85.7% of image): 2
#       - No coin detected; Mask too large (81.6% of image): 3
#       - No coin detected; Mask too large (85.8% of image): 2
#       - No coin detected; Mask too large (81.1% of image): 4
#       - No coin detected; Mask too large (83.3% of image): 3
#       - No coin detected; Mask too large (83.2% of image): 2
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 34.4): 2
#       - No coin detected; Image too dark (brightness: 12.6); Image too blurry (variance: 35.4): 1
#       - Coin in center (not corner); Image too dark (brightness: 13.8); Image too blurry (variance: 47.4): 1
#       - No coin detected; Image too dark (brightness: 9.8); Image too blurry (variance: 25.0): 1
#       - No coin detected; Image too blurry (variance: 41.4): 2
#       - No coin detected; Image too blurry (variance: 30.1): 1
#       - No coin detected; Mask too large (80.6% of image): 2
#       - No coin detected; Mask too large (87.3% of image): 4
#       - No coin detected; Image too blurry (variance: 35.4): 2
#       - No coin detected; Mask too large (82.1% of image): 4
#       - No coin detected; Mask too large (80.2% of image): 1
#       - No coin detected; Mask too large (80.1% of image): 1
#       - No coin detected; Mask too large (80.4% of image): 1
#       - No coin detected; Image too blurry (variance: 42.6): 2
#       - No coin detected; Image too bright (brightness: 225.7); Image too blurry (variance: 32.1): 2
#       - No coin detected; Mask too large (86.9% of image): 2
#       - No coin detected; Mask too large (82.4% of image): 2
#       - No coin detected; Image too blurry (variance: 49.6): 2
#       - No coin detected; Image too blurry (variance: 37.3): 2
#       - No coin detected; Mask too large (83.4% of image): 9
#       - No coin detected; Image too blurry (variance: 43.1): 2
#       - No coin detected; Image too blurry (variance: 13.9): 2
#       - No coin detected; Image too blurry (variance: 14.4): 2
#       - No coin detected; Image too blurry (variance: 11.3): 1
#       - No coin detected; Mask too large (100.0% of image): 3
#       - No coin detected; Mask too large (99.9% of image): 1
#       - No coin detected; Mask too large (83.9% of image): 3
#       - No coin detected; Mask too large (84.6% of image); Image too blurry (variance: 45.0): 1
#       - No coin detected; Mask too large (89.7% of image): 2
#       - No coin detected; Mask too large (88.7% of image): 3
#       - No coin detected; Mask too large (91.6% of image): 2
#       - No coin detected; Mask too large (91.5% of image): 3
#       - No coin detected; Image too blurry (variance: 47.9): 1
#       - No coin detected; Mask too large (96.5% of image): 2
#       - Mask too large (100.0% of image); Image too blurry (variance: 43.0): 1
#       - No coin detected; Image too blurry (variance: 44.8): 1
#       - No coin detected; Image too blurry (variance: 43.9): 2
#       - No coin detected; Mask too large (84.5% of image): 2
#       - No coin detected; Mask too large (84.7% of image): 2
#       - No coin detected; Mask too large (84.1% of image): 2
#       - No coin detected; Mask too large (82.6% of image): 2
#       - No coin detected; Image too blurry (variance: 45.9): 1
#       - No coin detected; Mask too large (84.0% of image): 5
#       - No coin detected; Image too dark (brightness: 27.9): 1
#       - No coin detected; Mask too large (90.0% of image): 2
#       - No coin detected; Mask too large (90.1% of image): 1
#       - No coin detected; Image too blurry (variance: 35.6): 2
#       - No coin detected; Image too blurry (variance: 36.2): 1
#       - No coin detected; Image too blurry (variance: 48.9): 1
#       - No coin detected; Image too blurry (variance: 34.7): 2
#       - No coin detected; Image too blurry (variance: 35.5): 1
#       - No coin detected; Image too blurry (variance: 38.7): 1
#       - No coin detected; Image too blurry (variance: 26.7): 1
#       - No coin detected; Mask too large (87.7% of image): 2
#       - No coin detected; Mask too large (80.9% of image): 2
#       - No coin detected; Mask too large (87.5% of image): 1
#       - No coin detected; Mask too large (88.6% of image): 2
#       - No coin detected; Mask too large (94.9% of image): 2
#       - Coin in center (not corner); Mask too large (82.6% of image); Image too blurry (variance: 46.5): 1
#       - No coin detected; Mask too large (98.5% of image): 1
#       - No coin detected; Mask too large (99.6% of image): 1
#       - No coin detected; Mask too large (95.9% of image): 1
#       - Mask too large (92.6% of image); Image too blurry (variance: 46.1): 1
#       - No coin detected; Mask too large (84.2% of image): 1
#       - No coin detected; Image too blurry (variance: 29.6): 2
#       - No coin detected; Image too blurry (variance: 30.4): 1
#       - Coin in center (not corner); Mask too large (100.0% of image); Image too blurry (variance: 46.0): 1
#       - No coin detected; Mask too large (80.3% of image): 1
#       - No coin detected; Image too blurry (variance: 46.8): 1
#       - No coin detected; Image too blurry (variance: 35.9): 1
#       - No coin detected; Image too blurry (variance: 49.0): 1
#       - No coin detected; Mask too large (82.8% of image): 1
#       - No coin detected; Mask too large (81.9% of image): 1
#       - No coin detected; Image too dark (brightness: 29.8): 1
#       - No coin detected; Image too blurry (variance: 45.6): 1
#       - No coin detected; Mask too large (82.0% of image): 1
#       - No coin detected; Image too dark (brightness: 28.9): 1
#       - Coin in center (not corner); Mask too large (80.1% of image); Image too blurry (variance: 37.4): 1
#       - No coin detected; Mask too large (87.9% of image): 2
#
# Total skipped files: 4346
#    Saved to: skipped_files.csv
#
# ======================================================================
# CREATING COMPARISON REPORT
# ======================================================================
#
# COMPARISON STATISTICS:
#      method  count  skipped  success_rate  avg_area  std_area  min_area  max_area  coin_detected  coin_in_corner
# binary_gray   6956     1508          82.2    380.27    460.36      0.07   4495.63           6956            5249
#  binary_hsv   7755      709          91.6    136.53    409.29      0.07   4386.97           7755            6048
#     opening   7755      709          91.6    130.55    406.73      0.07   4381.64           7755            6048
#     closing   7755      709          91.6    131.10    408.00      0.07   4383.11           7755            6048
# hole_filled   7753      711          91.6    155.20    509.55      0.08   5174.53           7753            6048
#
# Files saved:
#    - comparison_area_by_method.csv
#    - comparison_statistics.csv
#    - skipped_files.csv

# %%
print(f"\n{'='*70}")
print(f"FINAL SUMMARY")
print(f"{'='*70}")
print(f"⏱Total time: {elapsed:.2f}s")
print(f"Methods processed: {len(all_results)}")

total_processed = sum(stats['success'] for stats in all_stats.values())
total_skipped = sum(stats['skipped'] for stats in all_stats.values())
total_all = sum(stats['total'] for stats in all_stats.values())

print(f"\nOverall Statistics:")
print(f"   Total files: {total_all}")
print(f"   Processed: {total_processed} ({total_processed/total_all*100:.1f}%)")
print(f"   Skipped: {total_skipped} ({total_skipped/total_all*100:.1f}%)")
print(f"\nTime saved by skipping: ~{total_skipped * 0.5:.1f}s")
print(f"{'='*70}")
# Out:
# ======================================================================
# FINAL SUMMARY
# ======================================================================
# ⏱Total time: 30294.47s
# Methods processed: 5
#
# Overall Statistics:
#    Total files: 42320
#    Processed: 37974 (89.7%)
#    Skipped: 4346 (10.3%)
#
# Time saved by skipping: ~2173.0s
# ======================================================================

# %%
import shutil   # <-- tambahin import ini kalau belum ada

# Folder khusus untuk gambar yang di-skip (original + mask)
SKIPPED_IMAGES_DIR = os.path.join(MEASUREMENT_DIR, 'skipped_images')
os.makedirs(SKIPPED_IMAGES_DIR, exist_ok=True)

# %%
def process_image_with_measurement(image_path, segmented_mask_path, output_dir, method_name, enable_quality_check=True):
    original = cv2.imread(image_path)
    mask = cv2.imread(segmented_mask_path, cv2.IMREAD_GRAYSCALE)
    if original is None or mask is None:
        return None

    if original.shape[:2] != mask.shape[:2]:
        mask = cv2.resize(mask, (original.shape[1], original.shape[0]), interpolation=cv2.INTER_NEAREST)

    pixels_per_cm, coin_info = detect_coin_for_calibration(original)

    if enable_quality_check:
        is_valid, skip_reason, quality_score = check_image_quality(original, mask, coin_info)
        if not is_valid:
            # === BAGIAN BARU: SIMPAN ORIGINAL + MASK KE FOLDER SKIPPED_IMAGES ===
            stem = Path(image_path).stem
            skip_folder = os.path.join(SKIPPED_DIR, f"{stem}_{method_name}")
            os.makedirs(skip_folder, exist_ok=True)

            shutil.copy(image_path, os.path.join(skip_folder, Path(image_path).name))
            shutil.copy(segmented_mask_path, os.path.join(skip_folder, Path(segmented_mask_path).name))

            with open(os.path.join(skip_folder, "skip_reason.txt"), "w") as f:
                f.write(f"Method: {method_name}\n")
                f.write(f"Reason: {skip_reason}\n")
                f.write(f"Quality Score: {quality_score:.1f}\n")
            # ===========================================================

            return {
                'filename': Path(image_path).name,
                'method': method_name,
                'skipped': True,
                'skip_reason': skip_reason,
                'quality_score': round(quality_score, 2)
            }

    # Kalau lolos quality check → proses normal
    area_info = calculate_wound_area(mask, pixels_per_cm)
    coin_area_cm2 = np.pi * (coin_info['diameter_cm']/2)**2 if coin_info else None
    ratio_info = calculate_wound_ratio(area_info['area_cm2'], coin_area_cm2)

    measurement_result = {
        'filename': Path(image_path).name,
        'method': method_name,
        'skipped': False,
        'coin_detected': coin_info is not None,
        'coin_info': coin_info,
        'area_info': area_info,
        'ratio_info': ratio_info
    }

    vis = create_visualization(original, mask, coin_info, area_info, ratio_info, method_name)
    out_path = Path(output_dir) / f"measured_{Path(image_path).name}"
    cv2.imwrite(str(out_path), vis)
    measurement_result['output_path'] = str(out_path)

    return measurement_result

# %%
# PILIH METHOD YANG MAU DIPROSES
METHODS_TO_PROCESS = ['binary_gray', 'binary_hsv', 'opening', 'closing', 'hole_filled']

# MULAI PENGUKURAN + AUTO-SKIP + SIMPAN KE skipped_images
start_time = time.time()

all_results, all_stats, all_skipped = batch_area_measurement_multi_method(
    original_dir=AUGMENTED_DIR,
    segmented_dir=SEGMENTED_DIR,
    output_base_dir=MEASUREMENT_DIR,
    methods=METHODS_TO_PROCESS,
    enable_quality_check=True   # True = skip gambar jelek & simpan ke folder skipped_images
)

# Bikin laporan perbandingan
if all_results:
    create_comparison_report(all_results, all_stats, MEASUREMENT_DIR)

print(f"\nSELESAI dalam {time.time() - start_time:.1f} detik")
print(f"Gambar yang di-skip otomatis tersimpan di:\n   {SKIPPED_IMAGES_DIR}")
# Out:
# ======================================================================
# MULTI-METHOD MEASUREMENT WITH QUALITY FILTERING
# ======================================================================
# Methods to process: 5
# Quality check: ENABLED ✅
# ======================================================================
#
#
# ======================================================================
# Processing Method: BINARY_GRAY
# ======================================================================
# Files found: 8464
# 📏 binary_gray:   0%|          | 0/8464 [00:00<?, ?img/s]
# ❌ Error: binary_gray_burn_wound_2169_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2169_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2169_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2169_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2730_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2730_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2730_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2730_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2730_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1159_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1703_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1703_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1703_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1703_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1703_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2472_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2472_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2472_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2472_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2472_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2675_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0899_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1185_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1185_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1185_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1185_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2648_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2648_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2648_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2648_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2648_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2264_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0119_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0119_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0119_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0119_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2636_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2636_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2636_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2636_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3793_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3793_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3793_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3793_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3793_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1258_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1258_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1258_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1258_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1258_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1502_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1502_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1502_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1502_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0149_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1506_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1506_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1506_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0541_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2294_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2294_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2294_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2294_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1393_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1393_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1154_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1154_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1154_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1154_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1175_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1175_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1007_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1007_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1007_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1007_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1007_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0185_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0185_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0185_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0185_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0185_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0867_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0867_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1053_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1053_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1053_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1053_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1053_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0945_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0945_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0945_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0945_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1519_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1519_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1519_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1519_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0239_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1303_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1875_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1875_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1875_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1875_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1875_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0535_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3979_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3979_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3979_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3979_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0388_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0388_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0388_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0388_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0388_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1699_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1699_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_4060_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_4060_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_4060_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_4060_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0345_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0345_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0345_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0345_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0345_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3600_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3672_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0674_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0674_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0674_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0674_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0674_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2273_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2273_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2273_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2273_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2273_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2199_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0150_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0150_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0150_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0150_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0150_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2849_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0223_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0223_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0223_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0223_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0223_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3196_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3196_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3196_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3196_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2258_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1691_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1302_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1302_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1302_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0383_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0383_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0383_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0383_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0383_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0964_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0964_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0964_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1293_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1261_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1261_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1261_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1261_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1261_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0064_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0064_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0099_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0099_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0489_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0174_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0174_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0174_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0174_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0174_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2038_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2038_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2038_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2038_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1213_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1213_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1213_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1213_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1213_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3998_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3998_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3998_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3998_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3998_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1938_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1938_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1938_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1938_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1938_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3982_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3982_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3982_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3982_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1638_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1638_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1638_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1638_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1638_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0822_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0822_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0852_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0852_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3424_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0476_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3984_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3538_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3538_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3538_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3538_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3538_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0891_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0891_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0891_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0891_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0767_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3683_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3785_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3785_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3785_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3785_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3785_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1876_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1876_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1876_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1876_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1144_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1423_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1394_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1394_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1394_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1394_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1394_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0292_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0292_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0292_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0292_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0292_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0264_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0744_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0744_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0744_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0744_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0744_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3329_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0192_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0192_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0192_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2690_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0360_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3680_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3680_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3680_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3680_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0323_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0323_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0323_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0323_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3784_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3784_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3784_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3784_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1730_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1730_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1730_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1730_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0394_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0394_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0394_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0192_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0192_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2323_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2323_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2323_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0225_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0012_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2552_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2552_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2552_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2552_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1514_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2127_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2127_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2127_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2127_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0983_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0983_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0983_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1408_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1408_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1408_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1408_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1408_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0430_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0430_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0430_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0430_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1529_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1001_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1001_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1001_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2420_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2420_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2420_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2420_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0011_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0011_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0011_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0011_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2811_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2811_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2811_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2811_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2811_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1029_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1029_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2323_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0041_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0041_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0041_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0041_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0041_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2693_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0797_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0592_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0592_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0592_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0592_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2442_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0356_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0356_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0356_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0356_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0356_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2179_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1335_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2775_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2775_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2066_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2066_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2066_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2066_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2066_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1841_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1841_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1841_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1841_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1841_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3249_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3249_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3249_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3249_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3249_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3658_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0934_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0934_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0934_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0934_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0934_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0642_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0332_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0750_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0750_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0750_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0750_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0750_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2486_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2486_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2486_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2486_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1795_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1795_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1795_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1795_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1915_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1915_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1915_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1915_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1915_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0704_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0704_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0704_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0704_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2567_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2567_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2559_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2559_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2559_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2559_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2559_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2714_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2714_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2714_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2714_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2714_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1819_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1819_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1819_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1819_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1819_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2226_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2226_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2226_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2226_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3608_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1307_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1307_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1307_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1307_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1307_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3489_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2133_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2133_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2133_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2133_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1697_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0680_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0680_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0680_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0680_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2748_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2748_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2748_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2748_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2748_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1151_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2936_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2936_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2936_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2936_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1485_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1485_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2570_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2570_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2570_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2570_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2570_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2015_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2015_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2015_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2015_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1392_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1392_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1392_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1392_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1764_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2830_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2830_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2830_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2830_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1363_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1363_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1363_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1363_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1363_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1556_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1556_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1556_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1556_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1556_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1688_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1688_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1688_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1688_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1688_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1288_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1288_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1288_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1288_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1288_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0615_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0858_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0858_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0858_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2589_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2589_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2589_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2589_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0365_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0365_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0365_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0365_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0365_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0505_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0505_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0505_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0505_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1544_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1544_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1544_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1544_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1544_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1626_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1626_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1626_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1626_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1626_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0596_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0596_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0596_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0596_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1600_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1600_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1600_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1600_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0989_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0989_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0989_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1271_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1271_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2519_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2519_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_2519_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1133_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0161_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0161_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0161_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0161_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0161_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_1609_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0860_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0860_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0860_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0860_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_0860_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3144_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: binary_gray_burn_wound_3717_horizontal_flip.jpg - name 'shutil' is not defined
# ...
# ❌ Error: opening_burn_wound_0356_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0356_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0356_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0356_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0356_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0642_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0332_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0750_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0750_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0750_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0750_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0750_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0704_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0704_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0704_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0704_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1697_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0680_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0680_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0680_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0680_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1151_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1485_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1485_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1392_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1392_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1392_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1392_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_2830_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_2830_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_2830_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_2830_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1363_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1363_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1363_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1363_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1363_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1288_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1288_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1288_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1288_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1288_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0615_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0858_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0858_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0858_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0365_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0365_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0365_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0365_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0365_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0505_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0505_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0505_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0505_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1544_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1544_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1544_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1544_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1544_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1626_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1626_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1626_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1626_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1626_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0596_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0596_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0596_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0596_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1600_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1600_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1600_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1600_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0989_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0989_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0989_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1271_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1271_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1133_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0161_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0161_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0161_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0161_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0161_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1609_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0860_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0860_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0860_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0860_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0860_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_3589_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_3589_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_3589_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_3589_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1426_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1297_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1297_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1297_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1297_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1297_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0431_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0431_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0431_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0431_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0812_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0992_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0992_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0992_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0992_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_3798_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_3798_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_3798_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0088_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0088_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0088_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0088_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0088_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1290_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1290_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1290_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1523_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1523_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1523_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1523_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1523_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1432_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0831_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0831_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0831_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0831_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0831_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0931_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0931_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0931_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0931_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1167_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0396_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0396_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0396_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0396_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0585_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1505_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1352_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1352_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1352_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1352_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1352_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0055_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0093_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1434_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1434_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1434_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0171_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0171_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0070_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0070_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0070_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0070_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0059_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0059_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0059_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0059_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1646_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0251_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0142_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0142_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0142_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1109_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1109_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1109_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1109_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1109_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0146_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0146_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0146_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0146_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0146_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1046_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1046_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1578_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1578_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1578_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1578_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_1157_brightness_decrease.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0184_horizontal_flip.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0184_rotation_90.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0184_rotation_180.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0184_brightness_increase.jpg - name 'shutil' is not defined
# ❌ Error: opening_burn_wound_0184_brightness_decrease.jpg - name 'shutil' is not defined

# %%
print(f"\n{'='*60}")
print(f"                RINGKASAN AKHIR")
print(f"{'='*60}")

total_processed = sum(stats['total'] for stats in all_stats.values())
total_success   = sum(stats['success'] for stats in all_stats.values())
total_skipped   = sum(stats['skipped'] for stats in all_stats.values())
total_failed    = sum(stats['failed'] for stats in all_stats.values())

print(f"Total gambar diproses          : {total_processed}")
print(f"Berhasil diukur (valid)        : {total_success} gambar")
print(f"DI-SKIP karena kualitas jelek  : {total_skipped} gambar   <<<<<<")
print(f"Gagal (error baca file, dll)   : {total_failed}")
print(f"Success rate                   : {total_success/total_processed*100:.1f}%")

print(f"\nDetail per method:")
for method, stats in all_stats.items():
    print(f"  • {method.upper():12} → "
          f"{stats['success']:3} berhasil | "
          f"{stats['skipped']:3} di-skip | "
          f"{stats['total']} total")

print(f"\nSemua gambar yang di-skip sudah disimpan rapi di folder:")
print(f"   {SKIPPED_IMAGES_DIR}")
print(f"{'='*60}")
